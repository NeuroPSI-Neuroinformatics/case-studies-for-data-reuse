# %% [markdown]
# # Study of data reuse: Electrophysiological data of cortical layer 6 neurons and synaptically coupled neuronal pairs (v1)
#
# **Isaure Botherel and Andrew P. Davison**
#
# Paris-Saclay Institute of Neuroscience, CNRS, Université Paris-Saclay, France.
#
# April 2023
#
# ----

# %% [markdown]
# In this notebook we will look more closely at the EBRAINS dataset "[Electrophysiological data of cortical layer 6 neurons and synaptically coupled neuronal pairs (v1)](https://search.kg.ebrains.eu/instances/5b55cc01-8eb2-48fa-967d-d0c6c2c0e67d)", contributed by  Dirk Feldmeyer from the Institute of Neuroscience and Medicine of Jülich, Germany.
#
# As we can see from the dataset description,
#
# <i>This dataset provides a electrophysiological characterisation of cortical neurons and synaptically coupled neuronal pairs that is essential to understand their functions in brain microcircuits. Electrophysiological data were collected by using single or dual patch-clamp recordings from primary somatosensory (barrel) cortical layer 6 neurons in acute rat brain slices.</i> [[Data Descriptor](https://search.kg.ebrains.eu/instances/5b55cc01-8eb2-48fa-967d-d0c6c2c0e67d)].
#
# This dataset forms part of the results reported in:
#
#    Yang, D., Günter, R., Qi, G., Radnikow, G., & Feldmeyer, D. (2020). Muscarinic and Nicotinic Modulation of Neocortical Layer 6A Synaptic Microcircuits Is Cooperative and Cell-Specific. *Cerebral cortex* (New York, N.Y. : 1991), **30**(6), 3528–3542. https://doi.org/10.1093/cercor/bhz324
#
# In this notebook we will demonstrate how to access the data files and the metadata from this study, and how these data can be analysed and visualised, with the goal of reproducing some of the figures from the article.

# %% [markdown]
# ## Downloading the dataset

# %%
token = "eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJfNkZVSHFaSDNIRmVhS0pEZDhXcUx6LWFlZ3kzYXFodVNJZ1RXaTA1U2k0In0.....xusozeAAorEzFwJtj8RYtfskAGHG0nbZ6mqCrmaf-piFqCL7Y1NAOKR7V-I5QhCfaxd3k0-7PQdcWeWKvFe3oimN1XEd3c9bvUQfmDg7UxN7jlo3cJBysvdz1VdnKRCGiOb6RoI0_MsnDLxkOUUO154WXCeO6i5G9LpSVDMNHFOS2oBSbZKfnGJvsqzFuF2yadvJA0Y-N6HwfFEUsJIi1MUu7rzfZh5LLxnbf9L_DcRUbWhA50eNqyoYUQohHxpeMICQ41RTDdIj-xXhf8DPvVBsUBwScy7kuc6gRM7dUHc-1YhBhkDq2wswXMIZ32S87_bjMTNY9wNTLyNaBsaVEQ"

# %%
from fairgraph import KGClient
import fairgraph.openminds.core as omcore

#client = KGClient(host="core.kg.ebrains.eu", token=clb_oauth.get_token())
client = KGClient(host="core.kg.ebrains.eu", token=token)
dataset = omcore.Dataset.by_name("Electrophysiological data of cortical layer 6 neurons and synaptically coupled neuronal pairs", client)
dataset_version = dataset.versions.resolve(client)

# %%
# This is a 17 GB dataset. On the Collaboratory, this should _not_ be downloaded into the Drive.
# Maybe only download the specific files we use in this notebook.
# zip_file = dataset_version.download("downloads", client)

# %%
# trying to use "unzip" on Mac OS: zip_file contains filenames with "Illegal byte sequence", e.g.
# Acetylcholine modulation in S1 cortex layer 6/Dose response curve (MEC)/BC 25062019 B/BC 25062019 B 1-�M.pxp

# ArchiveUtility seems to work.

# %% [markdown]
# ## Exploring the dataset
#
# The dataset has two top-level folders, `Acetylcholine modulation in S1 cortex layer 6` and `FoxP2 neurons in S1 cortex layer 6`. For now, we'll focus on the first of these. This contains six folders:
# - `dose response curve (atropine)`
# - `Dose response curve (MEC)`
# - `L6A paired ACh analysis`
# - `L6A paired-recodings OG data(ACh)`
# - `nicotinic analysis`
# - `SPon analysis DHßE TRO`
#
# ### Dose response curve (atropine)
#
# This folder contains a Numbers workbook with three sheets, some image files in Postscript format (.eps), and some Igor Pro files (.pxp). There is also a subfolder `dose response curve (atropine) analysis` which contains ten subfolders named something like `BC 12022019 A`, each presumably corresponding to recordings from one cell or a pair of cells. Each of these folders contains a number of Igor Pro files whose names contain a concentration in mM or µM, e.g. `300µM.pxp`, presumably corresponding to the applied concentration of atropine.
#
# ### Dose response curve (MEC)
#
# This folder contains an Excel workbook with a single sheet, some image files in Postscript format (.eps), and two Igor Pro files (.pxp). The image and Igor Pro files are in two groups, one with the prefix "DP" and the other "HP". [**At the moment, unclear what 'DP' and 'HP' stand for**] The image files show what appear to be dose-response curves, although there are no axis labels.
#
# The folder also contains 8 sub-folders named something like `BC 25062019 B`, each presumably corresponding to recordings from one cell or a pair of cells. Each of these folders contains a number of Igor Pro files whose names contain a concentration in µM, presumably corresponding to the applied concentration of MEC [**what is MEC?**], e.g. `BC 25062019 B 30µM.pxp`.
#
# ### L6A paired ACh analysis
#
# This folder contains three Excel workbooks, each containing multiple sheets, which appear to contain summary data from the analyses. There are three sub-folders, `e-e`, `e-i` and `i-e`, presumably relating to paired recordings of **e**xcitatory and **i**nhibitory neurons. Each of these sub-folders contains further folders, each named something like `BC 07042016 CD P20 analysis`, and containing files associated with one pair of recorded neurons. [**todo: check if any of the same names appear in the Dose response curve folder**]
#
# Each of these folders contains:
# - a single-page PDF file showing microscopy images and plots of recorded data.
# - a number of Postscript files showing plots of recorded data and graphs of analysis results.
# - a number of Igor Pro files, generally with similar names to the Postscript files (but there is not a 1-1 mapping), presumably containing data and analyses.
#
# ### L6A paired-recodings OG data(ACh)
#
# This folder appears to contain the original recordings (in HEKA Patchmaster format) that were then analysed with Igor Pro. Of the 58 data subfolders in the `L6A paired ACh analysis` folder all but three have corresponding folders here. It should be noted that some of the "original data" folders correspond to two "analysis" folders. In all cases, these are in the `E-I:I-E` folder, so presumably both connection directions were analysed separately.
#
# Also of note is folder "BC 22112017 CD1" in the analysis `e-e` folder, which seems to match an original data folder in the `E-I:I-E` folder.
#
# In addition to the `E-E` and `E-I:I-E` folders, there are two folders named after years, `2018` and `2019`, which have further subfolders named by month. These appear to contain the same data as `E-E` and `E-I:I-E`. [**todo: check if there is extra data in the year/month folders that didn't make it into E-E and E-I:I-E**]
#
# ### Nicotinic analysis
#
# todo
#
# ### SPon analysis DHßE TRO
#
# todo

# %% [markdown]
# ## Replicating figures from Yang et al., 2020

# %% [markdown]
# ### Fig 5d

# %%
# Read data from Excel spreadsheet

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data_dir = "downloads/hbp-d002323_NeuromodNeocortex-EPhys_pub/Acetylcholine modulation in S1 cortex layer 6/L6A paired ACh analysis"
ex_to_ex = pd.read_excel(
    f"{data_dir}/ Ach effec on L6A PSP.xls", 
    sheet_name="Ex.-to-Ex.", 
    skiprows=[1, 2], 
    nrows=25,
    na_values="-"
)
ex_to_inh = pd.read_excel(
    f"{data_dir}/ Ach effec on L6A PSP.xls", 
    sheet_name="Ex.-to-FS or non-FS", 
    skiprows=[1, 2], 
    nrows=9,
    na_values="-"
)

cc_cc = ex_to_ex.loc[ex_to_ex["Morphology comment"].isin(["CC-CC", "CC-(bip)CC"])]
cc_ct = ex_to_ex.loc[ex_to_ex["Morphology comment"] == "CC-CT"]
cc_inh = ex_to_inh

# %%
epsp_amplitude = {
    "Ctrl": {
        "CC-CC": {
            "mean": cc_cc["Amp.  control"].mean(),
            "stdev": cc_cc["Amp.  control"].std()
        },
        "CC-CT": {
            "mean": cc_ct["Amp.  control"].mean(),
            "stdev": cc_ct["Amp.  control"].std()
        },
        "CC-interneuron": {
            "mean": cc_inh["Amp.  control"].mean(),
            "stdev": cc_inh["Amp.  control"].std()
        }
    },
    "ACh": {
        "CC-CC": {
            "mean": cc_cc["Amp. Ach30µM"].mean(),
            "stdev": cc_cc["Amp. Ach30µM"].std()
        },
        "CC-CT": {
            "mean": cc_ct["Amp. Ach30µM"].mean(),
            "stdev": cc_ct["Amp. Ach30µM"].std()
        },
        "CC-interneuron": {
            "mean": cc_inh["Amp. Ach30"].mean(),
            "stdev": cc_inh["Amp. Ach30"].std()
        }
    }
}

# %%
paired_pulse_ratio = {
    "Ctrl": {
        "CC-CC": {
            "mean": cc_cc["PPR control"].mean(),
            "stdev": cc_cc["PPR control"].std()
        },
        "CC-CT": {
            "mean": cc_ct["PPR control"].mean(),
            "stdev": cc_ct["PPR control"].std()
        },
        "CC-interneuron": {
            "mean": cc_inh["PPR control"].mean(),
            "stdev": cc_inh["PPR control"].std()
        }
    },
    "ACh": {
        "CC-CC": {
            "mean": cc_cc["PPR Ach 30"].mean(),
            "stdev": cc_cc["PPR Ach 30"].std()
        },
        "CC-CT": {
            "mean": cc_ct["PPR Ach 30"].mean(),
            "stdev": cc_ct["PPR Ach 30"].std()
        },
        "CC-interneuron": {
            "mean": cc_inh["PPR Ach 30"].mean(),
            "stdev": cc_inh["PPR Ach 30"].std()
        }
    }
}

# %%
coefficient_of_variation = {
    "Ctrl": {
        "CC-CC": {
            "mean": cc_cc["CV control"].mean(),
            "stdev": cc_cc["CV control"].std()
        },
        "CC-CT": {
            "mean": cc_ct["CV control"].mean(),
            "stdev": cc_ct["CV control"].std()
        },
        "CC-interneuron": {
            "mean": cc_inh["CV control"].mean(),
            "stdev": cc_inh["CV control"].std()
        }
    },
    "ACh": {
        "CC-CC": {
            "mean": cc_cc["CV Ach30"].mean(),
            "stdev": cc_cc["CV Ach30"].std()
        },
        "CC-CT": {
            "mean": cc_ct["CV Ach30"].mean(),
            "stdev": cc_ct["CV Ach30"].std()
        },
        "CC-interneuron": {
            "mean": cc_inh["CV Ach30"].mean(),
            "stdev": cc_inh["CV Ach30"].std()
        }
    }
}

# %%
failure_rate = {
    "Ctrl": {
        "CC-CC": {
            "mean": cc_cc["Failure  CTR"].mean(),
            "stdev": cc_cc["Failure  CTR"].std()
        },
        "CC-CT": {
            "mean": cc_ct["Failure  CTR"].mean(),
            "stdev": cc_ct["Failure  CTR"].std()
        },
        "CC-interneuron": {
            "mean": cc_inh["Failure  CTR"].mean(),
            "stdev": cc_inh["Failure  CTR"].std()
        }
    },
    "ACh": {
        "CC-CC": {
            "mean": cc_cc["Failure  Ach30"].mean(),
            "stdev": cc_cc["Failure  Ach30"].std()
        },
        "CC-CT": {
            "mean": cc_ct["Failure  Ach30"].mean(),
            "stdev": cc_ct["Failure  Ach30"].std()
        },
        "CC-interneuron": {
            "mean": cc_inh["Failure  Ach30"].mean(),
            "stdev": cc_inh["Failure  Ach30"].std()
        }
    }
}

# %%
def plot_statistics(data, axes, label, ylim, show_legend=False):
    """This function plots one of the panels as in Fig 5D"""
    
    y = (data["Ctrl"]["CC-CC"]["mean"], data["ACh"]["CC-CC"]["mean"])
    y1 = (data["Ctrl"]["CC-CT"]["mean"], data["ACh"]["CC-CT"]["mean"])
    y2 = (data["Ctrl"]["CC-interneuron"]["mean"], data["ACh"]["CC-interneuron"]["mean"])
    e = (data["Ctrl"]["CC-CC"]["stdev"], data["ACh"]["CC-CC"]["stdev"])
    e1 = (data["Ctrl"]["CC-CT"]["stdev"], data["ACh"]["CC-CT"]["stdev"])
    e2 = (data["Ctrl"]["CC-interneuron"]["stdev"], data["ACh"]["CC-interneuron"]["stdev"])
    x= [1,1.5,] 
    x1=[1.1,1.6]
    x2=[1.2,1.7]

    axes.errorbar(x, y, e, linestyle='None', marker='o',color='orange',label='CC-CC')
    axes.errorbar(x1, y1, e1, linestyle='None', marker='o',color='brown',label='CC-CT')
    axes.errorbar(x2, y2, e2, linestyle='None', marker='o',color='purple',label='CC-interneuron')
    axes.set_ylim(*ylim)
    axes.set_xticks(x1, ("Ctrl", "ACh"))
    axes.set_ylabel(label)
    axes.spines[['right', 'top']].set_visible(False)
    if show_legend:
        axes.legend()

# %% [markdown]
# ![low-res](https://oup.silverchair-cdn.com/oup/backfile/Content_public/Journal/cercor/30/6/10.1093_cercor_bhz324/1/m_bhz324f5.jpeg?Expires=1683289097&Signature=1vmDgK4Xc~PlP2BUJP30JTaFgcb7Ymhf48E7K4P~IsqfWZPjTc9u9Lmi5WDqhLSGCVYX0KKLwxCTuE-XO93CSqDiCTXRGjA8~BFRpiDCVpU6M4Gvan30SfBGjxUH2J5feZe6~RZ7kmt8xa0Iw4RyGTC5EFEi57PikVDvHJFO5bo7y4-4jCo54r6zL5McJjlkU8nqQCY5ndK89cxlaDIcZQEtMEwq10pjhJhHvi5ZJQ1WvnhtOkVFSbfy7sD7dBg3-luVb15xKAxmEhgEZClAEyhfsmGMqRygP2WWlVt0kzBGJu1Vt4~BjaO1CcZlbS8MO63uQqE5SLZA6ITPwmujvQ__&Key-Pair-Id=APKAIE5G5CRDK6RD3PGA)
#
# Figure 5 from Danqing Yang, Robert Günter, Guanxiao Qi, Gabriele Radnikow, Dirk Feldmeyer (2020) Muscarinic and Nicotinic Modulation of Neocortical Layer 6A Synaptic Microcircuits Is Cooperative and Cell-Specific, Cerebral Cortex 30(6): 3528–3542, https://doi.org/10.1093/cercor/bhz324. This figure is reproduced here under the Creative Commons CC-BY-NC licence.

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(10, 4))
plot_statistics(epsp_amplitude, ax1, 'Amplitude (mV)', ylim=(-0.1, 2))
plot_statistics(paired_pulse_ratio, ax2, 'Paired-Pulse Ratio', ylim=(0, 5))
plot_statistics(coefficient_of_variation, ax3, 'Coefficient of variation', ylim=(0, 2))
plot_statistics(failure_rate, ax4, 'Failure rate (%)', ylim=(-2, 100), show_legend=True)
plt.subplots_adjust(wspace=0.6)
plt.show()

# %% [markdown]
# ## PXP files

# %%
from neo import get_io

# %%
data_dir = "downloads/hbp-d002323_NeuromodNeocortex-EPhys_pub/Acetylcholine modulation in S1 cortex layer 6/L6A paired ACh analysis/e-e/BC 01092015 AB Anylasis P18"

# %%
from PIL import Image
pil_im = Image.open(f"{data_dir}/control.EPSF")
pil_im.load(scale=4)

# %%
pil_im
# Out:
# <PIL.EpsImagePlugin.EpsImageFile image mode=RGB size=2320x3204>

# %%
io = get_io(f"{data_dir}/Ach 30.pxp")

# %% [markdown]
# Unable to read this file, igor2 can't handle it. One issue is that it seems to use big-endian byte order, but even after changing that there are other errors.

# %%
data = io.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = io.read()
#
# File ~/dev/analysis/neo/neo/io/baseio.py:124, in BaseIO.read(self, lazy, **kargs)
#     121     if (hasattr(self, 'read_all_blocks') and
#     122             callable(getattr(self, 'read_all_blocks'))):
#     123         return self.read_all_blocks(lazy=lazy, **kargs)
# --> 124     return [self.read_block(lazy=lazy, **kargs)]
#     125 elif Segment in self.readable_objects:
#     126     bl = Block(name='One segment only')
#
# File ~/dev/analysis/neo/neo/io/igorproio.py:74, in IgorIO.read_block(self, lazy)
#      71 assert not lazy, 'This IO does not support lazy mode'
#      73 block = Block(file_origin=str(self.filename))
# ---> 74 block.segments.append(self.read_segment(lazy=lazy))
#      75 block.segments[-1].block = block
#      76 return block
#
# File ~/dev/analysis/neo/neo/io/igorproio.py:87, in IgorIO.read_segment(self, lazy)
#      85 if self.extension == 'pxp':
#      86     if not self._filesystem:
# ---> 87         _, self.filesystem = pxp.load(str(self.filename))
#      89     def callback(dirpath, key, value):
#      90         if isinstance(value, WaveRecord):
#
# File ~/dev/analysis/env-202304/lib/python3.9/site-packages/igor2/packed.py:82, in load(filename, strict, ignore_unknown)
#      80 data = bytes(f.read(header['numDataBytes']))
#      81 if len(data) < header['numDataBytes']:
# ---> 82     raise ValueError(
#      83         ('not enough data for the next record ({} < {})'
#      84          ).format(len(b), header['numDataBytes']))
#      85 record_type = _RECORD_TYPE.get(
#      86     header['recordType'] & PACKEDRECTYPE_MASK, _UnknownRecord)
#      87 logger.debug('the new record has type {} ({}).'.format(
#      88     record_type, header['recordType']))
#
# ValueError: not enough data for the next record (8 < 872415232)

# %%
data

# %%
debug
# Out:
# > /Users/adavison/dev/analysis/env-202304/lib/python3.9/site-packages/igor2/packed.py(82)load()
#      80             data = bytes(f.read(header['numDataBytes']))
#      81             if len(data) < header['numDataBytes']:
# ---> 82                 raise ValueError(
#      83                     ('not enough data for the next record ({} < {})'
#      84                      ).format(len(b), header['numDataBytes']))
#
# ipdb> pp header
# {'numDataBytes': 872415232, 'recordType': 2816, 'version': 0}
# ipdb> _RECORD_TYPE
# {0: <class 'igor2.record.base.UnusedRecord'>, 1: <class 'igor2.record.variables.VariablesRecord'>, 2: <class 'igor2.record.history.HistoryRecord'>, 3: <class 'igor2.record.wave.WaveRecord'>, 4: <class 'igor2.record.history.RecreationRecord'>, 5: <class 'igor2.record.procedure.ProcedureRecord'>, 6: <class 'igor2.record.base.UnusedRecord'>, 7: <class 'igor2.record.history.GetHistoryRecord'>, 8: <class 'igor2.record.packedfile.PackedFileRecord'>, 9: <class 'igor2.record.folder.FolderStartRecord'>, 10: <class 'igor2.record.folder.FolderEndRecord'>}
# ipdb> header['recordType'] & PACKEDRECTYPE_MASK
# 2816
# ipdb> PACKEDRECTYPE_MASK
# 32767
# ipdb> quit

# %%
segment = data[0].segments[0]

# %%
segment

# %%
for sig in segment.analogsignals:
    print(f"{sig.name} {sig.shape} {sig.units} {sig.sampling_rate}")

# %%
Vmem_L = segment.filter(name="Vmem_L")[0]
plt.plot(Vmem_L.times, Vmem_L)

Vmem_R = segment.filter(name="Vmem_R")[0]
plt.plot(Vmem_R.times, Vmem_R)

ach1 = segment.filter(name="ach1")[0]
plt.plot(ach1.times, ach1)

# %% [markdown]
# ### .dat files

# %%
data_dir = "downloads/hbp-d002323_NeuromodNeocortex-EPhys_pub/Acetylcholine modulation in S1 cortex layer 6/L6A paired-recodings OG data(ACh)/E-E/BC 01092015 AB"

# %%
from neo.io import StimfitIO

# %%
io = StimfitIO(f"{data_dir}/AB Ach.dat")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 io = StimfitIO(f"{data_dir}/AB Ach.dat")
#
# File ~/dev/analysis/neo/neo/io/stimfitio.py:95, in StimfitIO.__init__(self, filename)
#      89 """
#      90 Arguments:
#      91     filename : Either a filename or a stfio Recording object
#      92 """
#      93 # We need this module, so try importing now so that it fails on
#      94 # instantiation rather than read_block
# ---> 95 import stfio  # noqa
#      97 BaseIO.__init__(self)
#      99 if hasattr(filename, 'lower'):
#
# ModuleNotFoundError: No module named 'stfio'
